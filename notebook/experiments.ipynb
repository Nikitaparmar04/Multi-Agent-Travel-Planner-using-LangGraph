# %%
print("ok")
# Out:
# ok

# %%
from dotenv import load_dotenv

# %%
from langchain_groq import ChatGroq

# %%
llm= ChatGroq(model="llama-3.1-8b-instant")

# %%
llm.invoke("hii")
# Out:
# AIMessage(content='Hi there. Is there something I can help you with?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 37, 'total_tokens': 50, 'completion_time': 0.026756439, 'completion_tokens_details': None, 'prompt_time': 0.002249196, 'prompt_tokens_details': None, 'queue_time': 0.045897014, 'total_time': 0.029005635}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019eda5f-fb54-75a0-bbb2-82409a81d1f9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 13, 'total_tokens': 50})

# %%
from langchain_core.tools import StructuredTool

# %%
@StructuredTool
